# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline #Per a que tot els gràfics apareixquen en pantalla, ben ficats, etc...ningú sap per qué!

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]

# %%
plt.plot(x)
plt.xlabel("Eje de abcisas")
plt.ylabel("Eje de ordenadas")
# Out:
# Text(0, 0.5, 'Eje de ordenadas')

# %%
x = [1,2,3,4]
y = [1,4,9,16]
plt.plot(x, y)

# %%
import numpy as np

# %%
mu = 100
sigma = 20

x = mu + sigma * np.random.randn(10000)

# %%
x
# Out:
# array([118.28321529, 104.14927569,  67.7673832 , ..., 101.37258571,
#         88.54620451, 105.59177978])

# %%
np.random.randn(100)
# Out:
# array([-0.51105526,  2.40679362,  1.36709529,  1.13933871, -1.53071498,
#         1.77161051, -2.41597668,  0.63122298, -1.03273959, -0.55239634,
#        -0.82992064,  0.1898731 ,  0.26924372,  1.74673355,  1.18142485,
#         0.6445783 ,  0.60148093, -0.0517428 , -2.17639013, -0.08990971,
#         0.06409896,  0.62418071,  0.14509478,  0.60070052, -0.10728136,
#        -0.4364958 ,  0.5145698 ,  1.50091522, -0.6891436 ,  0.01320478,
#         0.16247739,  0.40243035,  0.320065  , -0.30361553, -0.35071207,
#        -0.47404411, -0.71267315,  0.42827156, -1.64288411, -0.71881891,
#         0.88181472, -0.75735594,  0.74657734,  1.27166432, -0.95066561,
#         0.52571006, -0.34968436,  0.08523745,  0.14446915, -0.04515532,
#         0.60925491, -0.36087485,  0.26156999, -0.05803306, -0.9392421 ,
#         1.13107303, -0.0523616 , -0.04025536, -0.17896799,  2.25863794,
#         0.12820653, -0.34524157,  0.05227553,  0.4747568 , -0.74217371,
# ...

# %%
np.mean(np.random.randn(100000))
# Out:
# 0.00022335938564716726

# %%
plt.plot(np.random.randn(10000), 'ro')
